# %%
cd Documents/Workshop/DeepLearning/
# Out:
# [WinError 3] The system cannot find the path specified: 'Documents/Workshop/DeepLearning/'
# C:\Users\aryan\Documents\Workshop\DeepLearning

# %% [markdown]
# # Importing the Libraries for Data Preprocessing

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Importing the Data Set

# %%
dataset = pd.read_csv('Churn_Modelling.csv')

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# ### Creation of the Matrix of Features and Dependent variable Vector

# %%
X = dataset.iloc[:, 3:13].values
Y = dataset.iloc[:, 13].values

# %% [markdown]
# ### Seperating out / Dealing with the Categorical Variable

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %% [markdown]
# ### Dealing with the Country categorical variable

# %%
labelEncoder_X_Country = LabelEncoder()
X[:, 1] = labelEncoder_X_Country.fit_transform(X[:, 1])

# %% [markdown]
# ### Dealing with the Gender categorical variable

# %%
labelEncoder_X_Gender = LabelEncoder()
X[:, 2] = labelEncoder_X_Gender.fit_transform(X[:, 2])

# %%
onehotencoder = OneHotEncoder(categorical_features=[1])
X = onehotencoder.fit_transform(X).toarray()
# Out:
# C:\Users\aryan\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\aryan\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %% [markdown]
# #### To avoid the Dummy variable trap

# %%
X = X[:, 1:]

# %% [markdown]
# ### Splitting the data into Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Scaling the Data ( Feature Scaling )

# %%
from sklearn.preprocessing import StandardScaler
SC = StandardScaler()
X_train = SC.fit_transform(X_train)
X_test = SC.transform(X_test)

# %% [markdown]
# ## Finally Done with the Data Preprocessing ! Kudos Everyone !!
#
# # Creating our First Neural Network ( ANN )
#
# ### Importing Keras, A library using which we will create the Neural Network

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
Our_Classifier = Sequential()

# %%
Our_Classifier.add(Dense(output_dim = 6, init = 'uniform', activation = 'relu', input_dim = 11))
# Out:
# C:\Users\aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=11, units=6, kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
Our_Classifier.add(Dense(output_dim = 6, init = 'uniform', activation = 'relu'))
# Out:
# C:\Users\aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=6, kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
Our_Classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'sigmoid'))
# Out:
# C:\Users\aryan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
Our_Classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
Our_Classifier.fit(X_train, Y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 8000/8000 [==============================] - 1s 117us/step - loss: 0.4816 - accuracy: 0.7960
# Epoch 2/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.4253 - accuracy: 0.7960
# Epoch 3/100
# 8000/8000 [==============================] - 1s 86us/step - loss: 0.4167 - accuracy: 0.8267
# Epoch 4/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.4110 - accuracy: 0.8340
# Epoch 5/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.4075 - accuracy: 0.8342
# Epoch 6/100
# 8000/8000 [==============================] - 1s 84us/step - loss: 0.4051 - accuracy: 0.8363
# Epoch 7/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.4028 - accuracy: 0.8347
# Epoch 8/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.4015 - accuracy: 0.8354
# Epoch 9/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.4006 - accuracy: 0.8338
# Epoch 10/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3999 - accuracy: 0.8338
# Epoch 11/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3986 - accuracy: 0.8366
# Epoch 12/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3988 - accuracy: 0.8367
# Epoch 13/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3980 - accuracy: 0.8361
# Epoch 14/100
# 8000/8000 [==============================] - 1s 84us/step - loss: 0.3982 - accuracy: 0.8353
# Epoch 15/100
# 8000/8000 [==============================] - 1s 84us/step - loss: 0.3973 - accuracy: 0.8345
# Epoch 16/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3971 - accuracy: 0.8356
# Epoch 17/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3971 - accuracy: 0.8371
# Epoch 18/100
# 8000/8000 [==============================] - 1s 85us/step - loss: 0.3963 - accuracy: 0.8365
# Epoch 19/100
# 8000/8000 [==============================] - 1s 93us/step - loss: 0.3968 - accuracy: 0.8371
# Epoch 20/100
# 8000/8000 [==============================] - 1s 86us/step - loss: 0.3956 - accuracy: 0.8361
# Epoch 21/100
# 8000/8000 [==============================] - 1s 91us/step - loss: 0.3956 - accuracy: 0.8379
# Epoch 22/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3950 - accuracy: 0.8361
# Epoch 23/100
# 8000/8000 [==============================] - 1s 86us/step - loss: 0.3947 - accuracy: 0.8381
# Epoch 24/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3952 - accuracy: 0.8375
# Epoch 25/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3945 - accuracy: 0.8365
# Epoch 26/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3946 - accuracy: 0.8381
# Epoch 27/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3949 - accuracy: 0.8364
# Epoch 28/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3943 - accuracy: 0.8365
# Epoch 29/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3943 - accuracy: 0.8381
# Epoch 30/100
# 8000/8000 [==============================] - 1s 84us/step - loss: 0.3945 - accuracy: 0.8372
# Epoch 31/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3941 - accuracy: 0.8369
# Epoch 32/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3940 - accuracy: 0.8393
# Epoch 33/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3939 - accuracy: 0.8378
# Epoch 34/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3929 - accuracy: 0.8388
# Epoch 35/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3931 - accuracy: 0.8364
# Epoch 36/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3934 - accuracy: 0.8355
# Epoch 37/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3931 - accuracy: 0.8379
# Epoch 38/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3928 - accuracy: 0.8397
# Epoch 39/100
# 8000/8000 [==============================] - 1s 84us/step - loss: 0.3928 - accuracy: 0.8380
# Epoch 40/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3918 - accuracy: 0.8385
# Epoch 41/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3918 - accuracy: 0.8381
# Epoch 42/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3915 - accuracy: 0.8393
# Epoch 43/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3914 - accuracy: 0.8382
# Epoch 44/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3910 - accuracy: 0.8389
# Epoch 45/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3909 - accuracy: 0.8385
# Epoch 46/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3903 - accuracy: 0.8390
# Epoch 47/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3897 - accuracy: 0.8399
# Epoch 48/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3886 - accuracy: 0.8403
# Epoch 49/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3854 - accuracy: 0.8405
# Epoch 50/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3800 - accuracy: 0.8415
# Epoch 51/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3726 - accuracy: 0.8449
# Epoch 52/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3656 - accuracy: 0.8450
# Epoch 53/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3599 - accuracy: 0.8516
# Epoch 54/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3566 - accuracy: 0.8545
# Epoch 55/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3539 - accuracy: 0.8559
# Epoch 56/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3527 - accuracy: 0.8587
# Epoch 57/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3517 - accuracy: 0.8577
# Epoch 58/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3504 - accuracy: 0.8600
# Epoch 59/100
# 8000/8000 [==============================] - 1s 84us/step - loss: 0.3496 - accuracy: 0.8581
# Epoch 60/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3482 - accuracy: 0.8583
# Epoch 61/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3476 - accuracy: 0.8610
# Epoch 62/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3468 - accuracy: 0.8616
# Epoch 63/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3463 - accuracy: 0.8616
# Epoch 64/100
# 8000/8000 [==============================] - 1s 86us/step - loss: 0.3444 - accuracy: 0.8650
# Epoch 65/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3447 - accuracy: 0.8604
# Epoch 66/100
# 8000/8000 [==============================] - 1s 84us/step - loss: 0.3438 - accuracy: 0.8625
# Epoch 67/100
# 8000/8000 [==============================] - 1s 86us/step - loss: 0.3435 - accuracy: 0.8589
# Epoch 68/100
# 8000/8000 [==============================] - 1s 86us/step - loss: 0.3425 - accuracy: 0.8614
# Epoch 69/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3422 - accuracy: 0.8612
# Epoch 70/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3410 - accuracy: 0.8640
# Epoch 71/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3418 - accuracy: 0.8627
# Epoch 72/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3407 - accuracy: 0.8624
# Epoch 73/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3390 - accuracy: 0.8625
# Epoch 74/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3399 - accuracy: 0.8611
# Epoch 75/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3391 - accuracy: 0.8620
# Epoch 76/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3393 - accuracy: 0.8624
# Epoch 77/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3386 - accuracy: 0.8624
# Epoch 78/100
# 8000/8000 [==============================] - 1s 85us/step - loss: 0.3383 - accuracy: 0.8626
# Epoch 79/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3373 - accuracy: 0.8629
# Epoch 80/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3380 - accuracy: 0.8626
# Epoch 81/100
# 8000/8000 [==============================] - 1s 91us/step - loss: 0.3378 - accuracy: 0.8619
# Epoch 82/100
# 8000/8000 [==============================] - 1s 84us/step - loss: 0.3368 - accuracy: 0.8650
# Epoch 83/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3369 - accuracy: 0.8619
# Epoch 84/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3364 - accuracy: 0.8630
# Epoch 85/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3367 - accuracy: 0.8629
# Epoch 86/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3364 - accuracy: 0.8627
# Epoch 87/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3368 - accuracy: 0.8608
# Epoch 88/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3361 - accuracy: 0.8625
# Epoch 89/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3356 - accuracy: 0.8654
# Epoch 90/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3354 - accuracy: 0.8615
# Epoch 91/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3357 - accuracy: 0.8621
# Epoch 92/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3355 - accuracy: 0.8620
# Epoch 93/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3346 - accuracy: 0.8625
# Epoch 94/100
# 8000/8000 [==============================] - 1s 82us/step - loss: 0.3353 - accuracy: 0.8650
# Epoch 95/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3355 - accuracy: 0.8616
# Epoch 96/100
# 8000/8000 [==============================] - 1s 84us/step - loss: 0.3347 - accuracy: 0.8614
# Epoch 97/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3350 - accuracy: 0.8629
# Epoch 98/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3348 - accuracy: 0.8633
# Epoch 99/100
# 8000/8000 [==============================] - 1s 80us/step - loss: 0.3352 - accuracy: 0.8612
# Epoch 100/100
# 8000/8000 [==============================] - 1s 83us/step - loss: 0.3347 - accuracy: 0.8626

# %%
Y_predicted = Our_Classifier.predict(X_test)

# %%
Y_predicted
# Out:
# array([[0.24968609],
#        [0.25502047],
#        [0.17177734],
#        ...,
#        [0.22528037],
#        [0.22183317],
#        [0.17674506]], dtype=float32)

# %%
Y_predicted = (Y_predicted>0.5)

# %%
Y_predicted
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
Y_predicted[345]
# Out:
# array([ True])

# %%
from sklearn.metrics import confusion_matrix
ConfusionMatrix = confusion_matrix(Y_test, Y_predicted)

# %%
ConfusionMatrix
# Out:
# array([[1517,   78],
#        [ 192,  213]], dtype=int64)
